# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# make                 object
# model                object
# engine_fuel_type     object
# transmission_type    object
# driven_wheels        object
# market_category      object
# vehicle_size         object
# vehicle_style        object
# dtype: object

# %%
strings = list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0                   6.0            manual   rear_wheel_drive              2.0
# 1                   6.0            manual   rear_wheel_drive              2.0
# 2                   6.0            manual   rear_wheel_drive              2.0
# 3                   6.0            manual   rear_wheel_drive              2.0
# 4                   6.0            manual   rear_wheel_drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         automatic    all_wheel_drive              4.0
# 11910               6.0         automatic    all_wheel_drive              4.0
# 11911               6.0         automatic    all_wheel_drive              4.0
# 11912               6.0         automatic    all_wheel_drive              4.0
# 11913               6.0         automatic  front_wheel_drive              4.0
#
#                              market_category vehicle_size  vehicle_style  \
# 0      factory_tuner,luxury,high-performance      compact          coupe
# 1                         luxury,performance      compact    convertible
# 2                    luxury,high-performance      compact          coupe
# 3                         luxury,performance      compact          coupe
# 4                                     luxury      compact    convertible
# ...                                      ...          ...            ...
# 11909             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11910             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11911             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11912             crossover,hatchback,luxury      midsize  4dr_hatchback
# 11913                                 luxury      midsize          sedan
#
#        highway_mpg  city_mpg  popularity   msrp
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %% [markdown]
# # Exploratory data analysis

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# city_mpg
# [19 20 18 17 16]
# 69
#
# popularity
# [3916 3105  819  617 1013]
# 48
#
# msrp
# [46135 40650 36350 29450 34500]
# 6049

# %%
import matplotlib.pyplot as ptl
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# distribution of price

# %%
sns.histplot(df.msrp)
# Out:
# <AxesSubplot:xlabel='msrp', ylabel='Count'>

# %%
sns.histplot(df.msrp, bins = 50)
# Out:
# <AxesSubplot:xlabel='msrp', ylabel='Count'>

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins = 50)
# Out:
# <AxesSubplot:xlabel='msrp', ylabel='Count'>

# %%
price_logs = np.log1p(df.msrp)

# %%
price_logs
# Out:
# 0        10.739349
# 1        10.612779
# 2        10.500977
# 3        10.290483
# 4        10.448744
#            ...
# 11909    10.739024
# 11910    10.945018
# 11911    10.832122
# 11912    10.838031
# 11913    10.274913
# Name: msrp, Length: 11914, dtype: float64

# %%
sns.histplot(price_logs, bins=50)
# Out:
# <AxesSubplot:xlabel='msrp', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
n = len(df)

n_val = int(n*0.2)
n_test = int(n*0.2)
n_train = n - n_val - n_test

# %%
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
df.iloc[:10]
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 5  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 6  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 7  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 8  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 9  bmw    1_series  2013  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
# 5               6.0            manual  rear_wheel_drive              2.0
# 6               6.0            manual  rear_wheel_drive              2.0
# 7               6.0            manual  rear_wheel_drive              2.0
# 8               6.0            manual  rear_wheel_drive              2.0
# 9               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
# 5                     luxury,performance      compact         coupe
# 6                     luxury,performance      compact   convertible
# 7                luxury,high-performance      compact         coupe
# 8                                 luxury      compact   convertible
# 9                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500
# 5           28        18        3916  31200
# 6           26        17        3916  44100
# 7           28        20        3916  39300
# 8           28        18        3916  36900
# 9           27        18        3916  37200

# %%
df_val = df.iloc[:n_val]
df_test = df.iloc[n_val:n_val + n_test]
df_train = df.iloc[n_val+n_test:]

# %%
idx = np.arange(n)
idx
# Out:
# array([    0,     1,     2, ..., 11911, 11912, 11913])

# %%
np.random.seed(3)
np.random.shuffle(idx)

# %%
df.iloc[idx[:10]]
# Out:
#                make         model  year                engine_fuel_type  \
# 8929          volvo           s70  2000                regular_unleaded
# 8806            gmc          s-15  1990                regular_unleaded
# 7233     oldsmobile  ninety-eight  1995                regular_unleaded
# 3535   aston_martin           dbs  2010     premium_unleaded_(required)
# 8763      chevrolet          s-10  2002                regular_unleaded
# 10192        toyota        tacoma  2016                regular_unleaded
# 11124         volvo           v60  2015                regular_unleaded
# 1065           audi            a4  2015     premium_unleaded_(required)
# 3461          dodge        dakota  2009                regular_unleaded
# 7776       infiniti           q50  2015  premium_unleaded_(recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 8929       190.0               5.0         automatic  front_wheel_drive
# 8806       105.0               4.0            manual   rear_wheel_drive
# 7233       225.0               6.0         automatic  front_wheel_drive
# 3535       510.0              12.0         automatic   rear_wheel_drive
# 8763       190.0               6.0         automatic   rear_wheel_drive
# 10192      278.0               6.0         automatic   four_wheel_drive
# 11124      325.0               6.0         automatic    all_wheel_drive
# 1065       220.0               4.0         automatic    all_wheel_drive
# 3461       210.0               6.0            manual   four_wheel_drive
# 7776       360.0               6.0         automatic    all_wheel_drive
#
#        number_of_doors                 market_category vehicle_size  \
# 8929               4.0                          luxury      midsize
# 8806               2.0                             NaN      compact
# 7233               4.0                             NaN        large
# 3535               2.0         exotic,high-performance      midsize
# 8763               2.0                     performance      compact
# 10192              4.0                             NaN      compact
# 11124              4.0         luxury,high-performance      midsize
# 1065               4.0                          luxury      midsize
# 3461               4.0                       flex_fuel      compact
# 7776               4.0  luxury,high-performance,hybrid      midsize
#
#              vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 8929                 sedan           24        17         870    2500
# 8806   extended_cab_pickup           25        21         549    2000
# 7233                 sedan           26        17          26    2000
# 3535           convertible           18        12         259  283900
# 8763    regular_cab_pickup           20        15        1385   21499
# 10192  extended_cab_pickup           23        18        2031   33310
# 11124                wagon           28        19         870   45150
# 1065                 sedan           31        22        3105   39700
# 3461       crew_cab_pickup           19        15        1851   28210
# 7776                 sedan           35        28         190   48600

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train + n_val]]
df_test = df.iloc[idx[n_train+ n_val:]]

# %%
df_train
# Out:
#                make         model  year                engine_fuel_type  \
# 8929          volvo           s70  2000                regular_unleaded
# 8806            gmc          s-15  1990                regular_unleaded
# 7233     oldsmobile  ninety-eight  1995                regular_unleaded
# 3535   aston_martin           dbs  2010     premium_unleaded_(required)
# 8763      chevrolet          s-10  2002                regular_unleaded
# ...             ...           ...   ...                             ...
# 3016      chevrolet      corvette  2017  premium_unleaded_(recommended)
# 8008     volkswagen        rabbit  2008                regular_unleaded
# 741           volvo           740  1990                regular_unleaded
# 3501          dodge          dart  2016                regular_unleaded
# 10274          ford      taurus_x  2008                regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 8929       190.0               5.0         automatic  front_wheel_drive
# 8806       105.0               4.0            manual   rear_wheel_drive
# 7233       225.0               6.0         automatic  front_wheel_drive
# 3535       510.0              12.0         automatic   rear_wheel_drive
# 8763       190.0               6.0         automatic   rear_wheel_drive
# ...          ...               ...               ...                ...
# 3016       455.0               8.0            manual   rear_wheel_drive
# 8008       170.0               5.0         automatic  front_wheel_drive
# 741        114.0               4.0            manual   rear_wheel_drive
# 3501       160.0               4.0            manual  front_wheel_drive
# 10274      260.0               6.0         automatic  front_wheel_drive
#
#        number_of_doors          market_category vehicle_size  \
# 8929               4.0                   luxury      midsize
# 8806               2.0                      NaN      compact
# 7233               4.0                      NaN        large
# 3535               2.0  exotic,high-performance      midsize
# 8763               2.0              performance      compact
# ...                ...                      ...          ...
# 3016               2.0         high-performance      compact
# 8008               2.0                hatchback      compact
# 741                4.0                   luxury      midsize
# 3501               4.0                      NaN      midsize
# 10274              4.0                crossover        large
#
#              vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 8929                 sedan           24        17         870    2500
# 8806   extended_cab_pickup           25        21         549    2000
# 7233                 sedan           26        17          26    2000
# 3535           convertible           18        12         259  283900
# 8763    regular_cab_pickup           20        15        1385   21499
# ...                    ...          ...       ...         ...     ...
# 3016           convertible           25        16        1385   69195
# 8008         2dr_hatchback           29        21         873   16675
# 741                  wagon           26        19         870    2000
# 3501                 sedan           39        27        1851   21095
# 10274                wagon           24        16        5657   29770
#
# [7150 rows x 16 columns]

# %%
idx
# Out:
# array([ 8929,  8806,  7233, ..., 11513,  1688,  5994])

# %%
idx[n_train+ n_val:]
# Out:
# array([ 1576,  5059,  2111, ..., 11513,  1688,  5994])

# %%
n_train, n_val
# Out:
# (7150, 2382)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train = df_train.reset_index(drop = True)

# %%
df_test = df_test.reset_index(drop = True)

# %%
df_val = df_val.reset_index(drop = True)

# %%
y_train = np.log1p(df_train.msrp.values)

# %%
y_val = np.log1p(df_val.msrp.values)

# %%
y_test = np.log1p(df_test.msrp.values)

# %%
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %%
len(y_train)
# Out:
# 7150

# %%
df_train.iloc[10]
# Out:
# make                            toyota
# model                           sienna
# year                              2016
# engine_fuel_type      regular_unleaded
# engine_hp                        266.0
# engine_cylinders                   6.0
# transmission_type            automatic
# driven_wheels          all_wheel_drive
# number_of_doors                    4.0
# market_category                    NaN
# vehicle_size                     large
# vehicle_style        passenger_minivan
# highway_mpg                         23
# city_mpg                            16
# popularity                        2031
# Name: 10, dtype: object

# %%
xi = [453, 11, 86]

# %%
w0 = 7.17 
w = [0.01,0.04,0.002]

# %%
def linear_regression(xi):
    n = len(xi)
    pred = w0
    
    for j in range(n):
        pred = pred + w[j]* xi[j]
    
    return pred

# %%
linear_regression(xi)
# Out:
# 12.312
